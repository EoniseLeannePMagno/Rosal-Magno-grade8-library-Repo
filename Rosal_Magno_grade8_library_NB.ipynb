# %% [markdown]
# <a href="https://colab.research.google.com/github/EoniseLeannePMagno/Rosal-Magno-grade8-library-Repo/blob/main/Rosal_Magno_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
url = "https://raw.githubusercontent.com/EoniseLeannePMagno/Rosal-Magno-grade8-library-Repo/refs/heads/main/books.json"
response = requests.get(url)
books = response.json()
print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
import firebase_admin
from firebase_admin import credentials, db
cred = credentials.Certificate("firebase_key.json")
firebase_admin.initialize_app(cred, {
 "databaseURL": "https://rosal-magno-grade8-library-db-default-rtdb.asia-southeast1.firebasedatabase.app/"
})
print("Firebase connected successfully!")
# Out:
# Firebase connected successfully!

# %%
import requests
import json
data = books
print("JSON file loaded")
ref = db.reference("books")
for book in data["books"]:
  ref.child(str(book["id"])).set(book)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
books_ref = db.reference("books")
books_data = books_ref.get()
print(books_data)
# Out:
# {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}

# %%
for book_id, info in books_data.items():
 print(info["title"])
# Out:
# Introduction to Python
# Data Structures Basics
# Web Development Essentials

# %%
for book_id, availability in books_data.items():
    print(f"Title: {title}, Availability: {availability}")
# Out:
# Title: Web Development Essentials, Availability: {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}
# Title: Web Development Essentials, Availability: {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}
# Title: Web Development Essentials, Availability: {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}

# %%
books_data = ref.get()
overall_total_stock = 0
for key, book in books_data.items():
    title = book["title"]
    author = book["author"]
    total_stock = book["details"]["copies"] + book["details"]["available"]
    print(f"Title: {title}, Author: {author}, Total Stock: {total_stock}\n")
    overall_total_stock += total_stock
print(f"Overall Total Stock: {overall_total_stock}")
# Out:
# Title: Introduction to Python, Author: Juan Dela Cruz, Total Stock: 8
#
# Title: Data Structures Basics, Author: Maria Santos, Total Stock: 6
#
# Title: Web Development Essentials, Author: Carlos Reyes, Total Stock: 12
#
# Overall Total Stock: 26
